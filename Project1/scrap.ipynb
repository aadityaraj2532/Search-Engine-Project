# %%
import requests
from bs4 import BeautifulSoup

url = "https://sitare.org/"

response = requests.get(url, verify=False)
soup = BeautifulSoup(response.text, "html.parser")

title = soup.title.get_text()
body = soup.body.get_text()
print("Title:", title)
print("Body:", body)
for link in soup.find_all("a"):
    print("Link: ", link.get("href"))
# Out:
# Title: Sitare Foundation | Education NGO by Shilpa and Amit Singhal
# Body:
#
#
#
#
# Our humble mission
#
# Transform fifty thousand lives through education by 2050.
#
#
#
#
#
#
#
#
#
#
#
# Sitare University - Scholarship based Computer Science B.Tech. degrees to talented students.
#
#                     Education is empowerment. Education gives us hope. Education has the power to uplift not only individuals, but the entire world. In today world, good education is not always accessible to the underprivileged in our society. There is tremendous potential and talent in these children, all they need is access to good education. At the Sitare Foundation, we believe in providing access to high quality education to the most talented underprivileged children in our society. We have embarked upon a humble mission. Our mission is to “Transform fifty thousand lives through education by 2050.”
#
# We are learning a lot. The challenge of educating underprivileged children is daunting, but that does not and will never deter us. We are taking a scientific,
#                       step-by-step approach to impact lives and societies
#                       through education. We aim to educate 50,000 students by
#                       2050. We know that after going through our seven-year
#                       program, our students will shine like Sitare (Hindi for
#                       Stars), and inspire millions in their own communities.
#
# We have partnered with Hope and Dreams Trust, an Indian non-profit to implement various educational programs in India.
#
#
#
#
#
#
#
#
#
# Shilpa and Amit Singhal
# Founders
#
#
#
#
# "Education is the only sustainable path out of poverty."
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Find us on Social Media
#
#
#
#
#
#
#
#
#
#
#
#
#                         Contact Us
#
#
#
# Email [email protected] Phone +1-650-305-5721
#
#
#
#                      Copyrights © 2026                     Sitare.org  All rights reserved
#
#
#
#
#
#
#
#
#
#
#
#
#
# Link:  /index.php
# Link:  news.php
# Link:  contact.php
# Link:  univ
# Link:  https://univ.sitare.org
# Link:  https://hopedreams.org
# Link:  https://www.facebook.com/SitareFoundation
# Link:  https://www.instagram.com/sitarefdn/
# Link:  https://twitter.com/sitarefdn
# Link:  https://www.linkedin.com/company/sitare-foundation/
# Link:  contact.php
# Link:  /cdn-cgi/l/email-protection#b8d1d6ded7f8cbd1ccd9cadd96d7cadf
# Link:  tel:+1-650-305-5721
# Link:  https://sitare.org/
# c:\Users\adity\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sitare.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
